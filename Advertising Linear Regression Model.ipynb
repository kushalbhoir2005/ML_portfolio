# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Step 1: Data Loading

# %%
# read data into a DataFrame
data = pd.read_csv(r"C:\Users\hp\Downloads\Advertising.csv",index_col=0)
data
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
print(data.dtypes)
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
data.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# ### Pre Assumptions

# %%
#Assumption 1: There should be no outliers in the data.
#Check using boxplot.
for i in data.columns:
    data.boxplot(column=i)
    plt.show()

# %%
# filtered the outliers
df = data[data["newspaper"]<90]
df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
data[data["newspaper"]>90].index
# Out:
# Index([17, 102], dtype='int64')

# %%
data.drop(data[data["newspaper"]>90].index,axis=0)
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
#Assumption 2:Assumption of Linearity:Every independent variable should have a
#linear relationship with the dependent variable.

sns.pairplot(data,x_vars=['TV', 'radio', 'newspaper'],
             y_vars=["sales"], kind='reg')
plt.show();

# %%
sns.lmplot(data=data,x="newspaper",y="sales")
plt.show();

# %%
#data.drop(["newspaper"],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
# create X and Y
X = data.loc[:,['TV', 'radio', 'newspaper']]
Y = data.loc[:,'sales']
#X=data.iloc[:,0:-1]
#Y=data.iloc[:,-1]

# %%
Y.shape
# Out:
# (200,)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (200, 3)
# (200,)

# %%
#Assumption of Normality: The dependent variable should follow an
#approximate normal distribution
sns.distplot(Y)
plt.show()

# %%
from scipy.stats import skew
skew(Y)
# Out:
# np.float64(0.4045082487061191)

# %%
"""
# Log transformation
import numpy as np
Y_log  = np.log(Y)
Y_log
"""
# Out:
# '\n# Log transformation\nimport numpy as np\nY_log  = np.log(Y)\nY_log\n'

# %%
X.hist(bins=10)
plt.show()

# %%
for i in X.columns:
    print(f"{i} : {skew(X[i])}")
# Out:
# TV : -0.06932836662244649
# radio : 0.0934668451108453
# newspaper : 0.8879959753085498

# %%
from scipy.stats import skew
#finding the skewness in each variable
data_num_skew = X.apply(lambda i: skew(i.dropna()))
#subsetting the variables that are highly skewed
data_num_skewed = data_num_skew[(data_num_skew > .75) | (data_num_skew < -.75)]

print(data_num_skew)
print(data_num_skewed)

#import numpy as np
# apply log + 1 transformation for all numeric features with skewness over .75
new = np.log1p(X["newspaper"])
# Out:
# TV          -0.069328
# radio        0.093467
# newspaper    0.887996
# dtype: float64
# newspaper    0.887996
# dtype: float64

# %%
sns.distplot(new)
plt.show();

# %%
#Assumption of no multicollinearity: There should be no multicollinearity
#between the independent variables
#multicollinearity is the relationship amongst the multiple independent variables
corr_df=X.corr(method="pearson")
print(corr_df)

sns.heatmap(corr_df,vmax=1.0,vmin=-1.0,annot=True)
plt.show()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %%
sns.heatmap(data.corr(method="pearson"),vmax=1.0,vmin=-1.0,annot=True)
plt.show()

# %%
sns.lmplot(data,x="TV",y="radio")
plt.show()

# %%
sns.lmplot(data,x="TV",y="newspaper")
plt.show()

# %%
sns.lmplot(data,x="newspaper",y="radio")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
vif_df = pd.DataFrame()
vif_df["features"] = X.columns
vif_df["VIF Factor"] = [vif(X.values, i) for i in range(X.shape[1])]
vif_df
# Out:
#     features  VIF Factor
# 0         TV    2.486772
# 1      radio    3.285462
# 2  newspaper    3.055245

# %%
#>1000-->test_size=0.3
# >1000 ---> data split(70% - 30%) - 70%(training) & 30%(testing)

#<1000-->test_size=0.2
#<1000 --> data split(80% - 20%) - 80%(training) & 20%(testing)

# %%
from sklearn.model_selection import train_test_split
#Split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2,
                                                    random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
print("Percent of train data",X_train.shape[0]/X.shape[0]*100)
# Out:
# (160, 3)
# (160,)
# (40, 3)
# (40,)
# Percent of train data 80.0

# %%
from sklearn.linear_model import LinearRegression
#create a model object
lm = LinearRegression()
#train the model object
lm.fit(X_train,Y_train)
 
# print intercept and coefficients
print(lm.intercept_)
print(lm.coef_)
# Out:
# 3.254097114418883
# [ 0.0437726   0.19343299 -0.00222879]

# %%
# pair the feature names with the coefficients
print(list(zip(X.columns, lm.coef_)))
# Out:
# [('TV', np.float64(0.04377260306304603)), ('radio', np.float64(0.19343298611600765)), ('newspaper', np.float64(-0.0022287928056053743))]

# %%
X1=0 #TV
X2=0 #radio
X3=0  #newspaper
Y_pred=3.2540971144188813+(0.0437726*X1)+(0.19343299*X2)+(-0.00222879*X3)
print(Y_pred)
# Out:
# 3.2540971144188813

# %%
X_test.shape
# Out:
# (40, 3)

# %%
#predict using the model
Y_pred=lm.predict(X_test)
print(Y_pred)
# Out:
# [18.1625299  12.92663232 18.0531098  23.64464668 20.70438374 14.28227997
#  14.94493548 21.38232981 21.17508238 12.73110461 24.00312134  7.21544071
#  12.24762152 19.24345998 19.38241854 13.45643798 19.6247089   9.2531648
#  21.13268075 20.90762408 15.53485445 10.92529369 22.82955184 15.8122438
#  17.42515749  8.16218669 11.89783444 12.70337575 21.74138085  7.96215368
#  12.50099965 20.45535282  4.72120047  4.72259288 16.75292333 15.75804986
#   6.74415499 17.73477354  9.01591827 13.617599  ]

# %%
new_df=pd.DataFrame()
new_df=X_test.copy()

new_df["Actual sales"]=Y_test
new_df["Predicted sales"]=Y_pred
new_df=new_df.reset_index().drop("index", axis=1)

# %%
new_df
# Out:
#        TV  radio  newspaper  Actual sales  Predicted sales
# 0   210.7   29.5        9.3          18.4        18.162530
# 1     8.7   48.9       75.0           7.2        12.926632
# 2   218.4   27.7       53.4          18.0        18.053110
# 3   283.6   42.0       66.2          25.5        23.644647
# 4   216.4   41.7       39.6          22.6        20.704384
# 5   147.3   23.9       19.1          14.6        14.282280
# 6   188.4   18.1       25.6          14.9        14.944935
# 7   198.9   49.4       60.0          23.7        21.382330
# 8   216.8   43.9       27.2          22.3        21.175082
# 9    17.2   45.9       69.3           9.3        12.731105
# 10  289.7   42.3       51.2          25.4        24.003121
# 11   66.1    5.8       24.2           8.6         7.215441
# 12   16.9   43.7       89.4           8.7        12.247622
# 13  220.5   33.2       37.9          20.1        19.243460
# 14  229.5   32.3       74.2          19.7        19.382419
# 15  102.7   29.6        8.4          14.0        13.456438
# 16  255.4   26.9        5.5          19.8        19.624709
# 17    5.4   29.9        9.4           5.3         9.253165
# 18  241.7   38.0       23.2          21.8        21.132681
# 19  205.0   45.1       19.6          22.6        20.907624
# 20  187.8   21.1        9.5          15.6        15.534854
# 21    0.7   39.6        8.7           1.6        10.925294
# 22  261.3   42.7       54.7          24.2        22.829552
# 23  110.7   40.6       63.2          16.0        15.812244
# 24  280.2   10.1       21.4          14.8        17.425157
# 25   18.8   21.7       50.4           7.0         8.162187
# 26   25.6   39.0        9.3           9.5        11.897834
# 27   44.5   39.3       45.1          10.4        12.703376
# 28  239.9   41.5       18.5          23.2        21.741381
# 29   19.6   20.1       17.0           7.6         7.962154
# 30  131.7   18.4       34.6          12.9        12.501000
# 31  228.0   37.7       32.0          21.5        20.455353
# 32   27.5    1.6       20.7           6.9         4.721200
# 33   28.6    1.5       33.0           7.3         4.722593
# 34  290.7    4.1        8.5          12.8        16.752923
# 35  276.7    2.3       23.7          11.8        15.758050
# 36   80.2    0.0        9.2           8.8         6.744155
# 37  284.3   10.6        6.4          15.0        17.734774
# 38   89.7    9.9       35.7          10.6         9.015918
# 39  222.4    3.4       13.1          11.5        13.617599

# %%
new_df["Actual sales"].plot(color="blue")
new_df["Predicted sales"].plot(color="orange")
plt.show()

# %%
print(lm.score(X_train, Y_train))
# Out:
# 0.9209087553499528

# %%
print(len(Y_test))
print(len(Y_pred))
# Out:
# 40
# 40

# %%
import sklearn
sklearn.metrics.mean_squared_error(Y_test,Y_pred)
# Out:
# 6.700486756528873

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np

r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)

mse = mean_squared_error(Y_test,Y_pred)
print("MSE:",mse)

mae = mean_absolute_error(Y_test,Y_pred)
print("MAE:",mae)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.8353672324670594
# MSE: 6.700486756528873
# MAE: 1.8850130310423154
# RMSE: 2.5885298446278098
# Adj R-square: 0.8328473431680857

# %%
print(Y_test.min())
print(Y_test.max())
# Out:
# 1.6
# 25.5

# %%
new_df
# Out:
#        TV  radio  newspaper  Actual sales  Predicted sales
# 0   210.7   29.5        9.3          18.4        18.162530
# 1     8.7   48.9       75.0           7.2        12.926632
# 2   218.4   27.7       53.4          18.0        18.053110
# 3   283.6   42.0       66.2          25.5        23.644647
# 4   216.4   41.7       39.6          22.6        20.704384
# 5   147.3   23.9       19.1          14.6        14.282280
# 6   188.4   18.1       25.6          14.9        14.944935
# 7   198.9   49.4       60.0          23.7        21.382330
# 8   216.8   43.9       27.2          22.3        21.175082
# 9    17.2   45.9       69.3           9.3        12.731105
# 10  289.7   42.3       51.2          25.4        24.003121
# 11   66.1    5.8       24.2           8.6         7.215441
# 12   16.9   43.7       89.4           8.7        12.247622
# 13  220.5   33.2       37.9          20.1        19.243460
# 14  229.5   32.3       74.2          19.7        19.382419
# 15  102.7   29.6        8.4          14.0        13.456438
# 16  255.4   26.9        5.5          19.8        19.624709
# 17    5.4   29.9        9.4           5.3         9.253165
# 18  241.7   38.0       23.2          21.8        21.132681
# 19  205.0   45.1       19.6          22.6        20.907624
# 20  187.8   21.1        9.5          15.6        15.534854
# 21    0.7   39.6        8.7           1.6        10.925294
# 22  261.3   42.7       54.7          24.2        22.829552
# 23  110.7   40.6       63.2          16.0        15.812244
# 24  280.2   10.1       21.4          14.8        17.425157
# 25   18.8   21.7       50.4           7.0         8.162187
# 26   25.6   39.0        9.3           9.5        11.897834
# 27   44.5   39.3       45.1          10.4        12.703376
# 28  239.9   41.5       18.5          23.2        21.741381
# 29   19.6   20.1       17.0           7.6         7.962154
# 30  131.7   18.4       34.6          12.9        12.501000
# 31  228.0   37.7       32.0          21.5        20.455353
# 32   27.5    1.6       20.7           6.9         4.721200
# 33   28.6    1.5       33.0           7.3         4.722593
# 34  290.7    4.1        8.5          12.8        16.752923
# 35  276.7    2.3       23.7          11.8        15.758050
# 36   80.2    0.0        9.2           8.8         6.744155
# 37  284.3   10.6        6.4          15.0        17.734774
# 38   89.7    9.9       35.7          10.6         9.015918
# 39  222.4    3.4       13.1          11.5        13.617599

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Downloads'

# %%
new_df["Residual"]=new_df["Actual sales"]-new_df["Predicted sales"]
new_df.to_excel("Sales Prediction.xlsx",header=True,index=True)
new_df
# Out:
#        TV  radio  newspaper  Actual sales  Predicted sales  Residual
# 0   210.7   29.5        9.3          18.4        18.162530  0.237470
# 1     8.7   48.9       75.0           7.2        12.926632 -5.726632
# 2   218.4   27.7       53.4          18.0        18.053110 -0.053110
# 3   283.6   42.0       66.2          25.5        23.644647  1.855353
# 4   216.4   41.7       39.6          22.6        20.704384  1.895616
# 5   147.3   23.9       19.1          14.6        14.282280  0.317720
# 6   188.4   18.1       25.6          14.9        14.944935 -0.044935
# 7   198.9   49.4       60.0          23.7        21.382330  2.317670
# 8   216.8   43.9       27.2          22.3        21.175082  1.124918
# 9    17.2   45.9       69.3           9.3        12.731105 -3.431105
# 10  289.7   42.3       51.2          25.4        24.003121  1.396879
# 11   66.1    5.8       24.2           8.6         7.215441  1.384559
# 12   16.9   43.7       89.4           8.7        12.247622 -3.547622
# 13  220.5   33.2       37.9          20.1        19.243460  0.856540
# 14  229.5   32.3       74.2          19.7        19.382419  0.317581
# 15  102.7   29.6        8.4          14.0        13.456438  0.543562
# 16  255.4   26.9        5.5          19.8        19.624709  0.175291
# 17    5.4   29.9        9.4           5.3         9.253165 -3.953165
# 18  241.7   38.0       23.2          21.8        21.132681  0.667319
# 19  205.0   45.1       19.6          22.6        20.907624  1.692376
# 20  187.8   21.1        9.5          15.6        15.534854  0.065146
# 21    0.7   39.6        8.7           1.6        10.925294 -9.325294
# 22  261.3   42.7       54.7          24.2        22.829552  1.370448
# 23  110.7   40.6       63.2          16.0        15.812244  0.187756
# 24  280.2   10.1       21.4          14.8        17.425157 -2.625157
# 25   18.8   21.7       50.4           7.0         8.162187 -1.162187
# 26   25.6   39.0        9.3           9.5        11.897834 -2.397834
# 27   44.5   39.3       45.1          10.4        12.703376 -2.303376
# 28  239.9   41.5       18.5          23.2        21.741381  1.458619
# 29   19.6   20.1       17.0           7.6         7.962154 -0.362154
# 30  131.7   18.4       34.6          12.9        12.501000  0.399000
# 31  228.0   37.7       32.0          21.5        20.455353  1.044647
# 32   27.5    1.6       20.7           6.9         4.721200  2.178800
# 33   28.6    1.5       33.0           7.3         4.722593  2.577407
# 34  290.7    4.1        8.5          12.8        16.752923 -3.952923
# 35  276.7    2.3       23.7          11.8        15.758050 -3.958050
# 36   80.2    0.0        9.2           8.8         6.744155  2.055845
# 37  284.3   10.6        6.4          15.0        17.734774 -2.734774
# 38   89.7    9.9       35.7          10.6         9.015918  1.584082
# 39  222.4    3.4       13.1          11.5        13.617599 -2.117599

# %% [markdown]
# ### Testing Phase --> Unseen data

# %%
invest = pd.DataFrame({"TV":[100,25,200,30,2],
                       "radio":[200,100,50,120,30],
                       "newspaper":[0,1,1.5,2,0]})
invest
# Out:
#     TV  radio  newspaper
# 0  100    200        0.0
# 1   25    100        1.0
# 2  200     50        1.5
# 3   30    120        2.0
# 4    2     30        0.0

# %%
Y_pred_inv = lm.predict(invest)
Y_pred_inv
# Out:
# array([46.31795464, 23.68948201, 21.67692384, 27.77477595,  9.1446319 ])

# %%
invest["Sales Pred"] = Y_pred_inv
invest
# Out:
#     TV  radio  newspaper  Sales Pred
# 0  100    200        0.0   46.317955
# 1   25    100        1.0   23.689482
# 2  200     50        1.5   21.676924
# 3   30    120        2.0   27.774776
# 4    2     30        0.0    9.144632

# %% [markdown]
# #### Model Tunning / Optimization

# %%
from sklearn.model_selection import train_test_split
#Split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,
                                                    random_state=10)

# %%
from sklearn.linear_model import Ridge
rid = Ridge()
rid.fit(X_train,Y_train)
"""
3.2540971144188813
[ 0.0437726   0.19343299 -0.00222879]
"""
# print intercept and coefficients
print (rid.intercept_)
print (rid.coef_)
# Out:
# 3.2541996504791584
# [ 0.0437726   0.19342655 -0.00222742]

# %%
Y_pred=rid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
"""R-squared: 0.8353672324670594
MSE: 6.700486756528875
MAE: 1.885013031042315
RMSE: 2.58852984462781
Adj R-square: 0.8328473431680857
"""

r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)

mse = mean_squared_error(Y_test,Y_pred)
print("MSE:",mse)

mae = mean_absolute_error(Y_test,Y_pred)
print("MAE:",mae)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.8353686978689225
# MSE: 6.700427115268361
# MAE: 1.8850316523450914
# RMSE: 2.588518324306081
# Adj R-square: 0.8328488309995693

# %%
from sklearn.linear_model import Lasso
las = Lasso()
las.fit(X_train,Y_train)
"""
3.2540971144188813
[ 0.0437726   0.19343299 -0.00222879]
"""
# print intercept and coefficients
print (las.intercept_)
print (las.coef_)
# Out:
# 3.336794058220317
# [ 0.04362374  0.18766033 -0.        ]

# %%
Y_pred = las.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
"""R-squared: 0.8353672324670594
MSE: 6.700486756528875
MAE: 1.885013031042315
RMSE: 2.58852984462781
Adj R-square: 0.8328473431680857
"""

r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)

mse = mean_squared_error(Y_test,Y_pred)
print("MSE:",mse)

mae = mean_absolute_error(Y_test,Y_pred)
print("MAE:",mae)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.8360506658527163
# MSE: 6.67267129537745
# MAE: 1.905696067365571
# RMSE: 2.5831514271094234
# Adj R-square: 0.8335412372688292

# %%
#OLS-->OLS(Y_train, X_train) # sklearn
#ols-->ols(Y~X1+X2+X3)  # statsmodels

# %%
#fit(X_train, Y_train)-->sklearn
#Y~X1+X2+X3,data=df-->statsmodels

# %%
new_df=pd.DataFrame()
new_df=X_train.copy()

new_df["sales"]=Y_train.copy()
new_df
# Out:
#         TV  radio  newspaper  sales
# 191   39.5   41.1        5.8   10.8
# 8    120.2   19.6       11.6   13.2
# 27   142.9   29.3       12.6   15.0
# 139   43.0   25.9       20.5    9.6
# 59   210.8   49.6       37.7   23.8
# ..     ...    ...        ...    ...
# 114  209.6   20.6       10.7   15.9
# 65   131.1   42.8       28.9   18.0
# 16   195.4   47.7       52.9   22.4
# 126   87.2   11.8       25.9   10.6
# 10   199.8    2.6       21.2   10.6
#
# [160 rows x 4 columns]

# %%
import statsmodels.formula.api as sm

# create a fitted model with all three features
lm_model = sm.ols(formula='sales ~ TV + radio + newspaper',
                  data=new_df).fit()

# print the coefficients
print(lm_model.params)
print(lm_model.summary())
# Out:
# Intercept    3.254097
# TV           0.043773
# radio        0.193433
# newspaper   -0.002229
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     605.5
# Date:                Tue, 23 Dec 2025   Prob (F-statistic):           1.09e-85
# Time:                        15:11:50   Log-Likelihood:                -276.62
# No. Observations:                 160   AIC:                             561.2
# Df Residuals:                     156   BIC:                             573.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2541      0.286     11.364      0.000       2.688       3.820
# TV             0.0438      0.001     32.429      0.000       0.041       0.046
# radio          0.1934      0.008     24.310      0.000       0.178       0.209
# newspaper     -0.0022      0.005     -0.415      0.679      -0.013       0.008
# ==============================================================================
# Omnibus:                       12.534   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.333
# Skew:                          -0.697   Prob(JB):                      0.00127
# Kurtosis:                       3.233   Cond. No.                         446.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y_pred_new=lm_model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

r2=r2_score(Y_test,Y_pred_new)
print(r2)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred_new))
print(rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.8353672324670592
# 2.5885298446278107
# 0.8328473431680856

# %%
import statsmodels.formula.api as sm

# create a fitted model with two features
lm_model = sm.ols(formula='sales ~ TV + radio', data=new_df).fit()

# print the coefficients
print(lm_model.params)
print(lm_model.summary())
# Out:
# Intercept    3.217026
# TV           0.043721
# radio        0.192425
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     912.9
# Date:                Tue, 23 Dec 2025   Prob (F-statistic):           3.47e-87
# Time:                        15:11:50   Log-Likelihood:                -276.70
# No. Observations:                 160   AIC:                             559.4
# Df Residuals:                     157   BIC:                             568.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2170      0.271     11.855      0.000       2.681       3.753
# TV             0.0437      0.001     32.616      0.000       0.041       0.046
# radio          0.1924      0.008     25.462      0.000       0.177       0.207
# ==============================================================================
# Omnibus:                       12.555   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.347
# Skew:                          -0.697   Prob(JB):                      0.00126
# Kurtosis:                       3.241   Cond. No.                         418.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y_pred_new=lm_model.predict(X_test)

from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

r2=r2_score(Y_test,Y_pred_new)
print(r2)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred_new))
print(rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.8354496662944217
# 2.5878817077378105
# 0.8329310387377037

# %%
#Assumption: Errors should be random
#checked using Residual v/s Fitted plot
model_fitted_y = lm_model.fittedvalues
sns.residplot(x=model_fitted_y, y='sales', data=new_df, lowess=True)
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.show()

# %%
#Assumption: Errors should follow a approximate normal distribution
#checked using Normal QQ plot
import statsmodels.api as sma
sma.qqplot(lm_model.resid, line='s')
plt.show()

# %%
#Assumption: Errors should follow a constant variance-->Homoskedasticity
#checked using Scale location plot
model_norm_residuals_abs_sqrt=np.sqrt(np.abs(lm_model.resid))

sns.regplot(x=lm_model.fittedvalues,
            y=model_norm_residuals_abs_sqrt,
              scatter=True, lowess=True)
plt.ylabel("Standarized residuals")
plt.xlabel("Fitted value")
plt.show()
